# %% [markdown]
# ## The Problem

# %%
# Importing libraries
import requests
from bs4 import BeautifulSoup

# Grab page with request
# url = "https://www.wildcodeschool.com/en-GB"                           #Sometimes the data is in the code!!
# url = "https://www.farfetch.com/pt/shopping/women/clothing-1/items.aspx?page=1&view=90&sort=3&category=136227"  #If you don't scroll down nothing happens
# url = "https://www.linkedin.com/feed/"                                   #How are you going to get access?
# url = "https://www.glassdoor.com/Job/portugal-jobs-SRCH_IL.0,8_IN195.htm"         #You need to insert info to get what you want
url = "https://www.amazon.com/"
html = requests.get(url)

# Turn into BS page
soup = BeautifulSoup(html.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Amazon.com
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %% [markdown]
# ## The Solution

# %%
# Install webdriver-manager
# !pip install webdriver-manager
# Out:
# ...
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# ...

# %%
from bs4 import BeautifulSoup

from getpass import getpass
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.amazon.com/")
# Out:
# [WDM] - Downloading: 100%|██████████| 6.46M/6.46M [00:00<00:00, 7.14MB/s]

# %%
# First thing I can do: grab the page
soup_selenium = BeautifulSoup(driver.page_source, 'html.parser')
print(soup_selenium.prettify())
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-hires a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.22.2-2022-12-01" data-platform="Win32" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js">
#   </script>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
# ...

# %%
# Search the links with beautiful soup
soup_selenium = BeautifulSoup(driver.page_source, 'html.parser')
print(soup_selenium.prettify())
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-hires a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.22.2-2022-12-01" data-platform="Win32" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js">
#   </script>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
# ...

# %%
# Finding url => working but take the all box "a class"

soup_selenium = BeautifulSoup(driver.page_source, 'html.parser')
items = soup_selenium.find_all('a', {"class": "a-link-normal see-more truncate-1line"})
items
#def find_url(item):
 # return items

    re.findall('https\S+jpg',str(img))
#url_list = list(map(find_url, items))
#url_list
# Out:
#   Input In [155]
#     re.findall('https\S+jpg',str(img))
#     ^
# IndentationError: unexpected indent

# %%
# Finding url => working but also bringing all the a class

soup_selenium = BeautifulSoup(driver.page_source, 'html.parser')
items = soup_selenium.find_all('a', href=True)
items
# Out:
# [<a aria-label="Amazon" class="nav-logo-link nav-progressive-attribute" href="/ref=nav_logo" id="nav-logo-sprites">
#  <span class="nav-sprite nav-logo-base"></span>
#  <span class="nav-sprite nav-logo-ext nav-progressive-content" id="logo-ext"></span>
#  <span class="nav-logo-locale">.us</span>
#  </a>,
#  <a aria-label="Choose a language for shopping." class="nav-a nav-a-2 icp-link-style-2" href="/customer-preferences/edit?ie=UTF8&amp;preferencesReturnUrl=%2F&amp;ref_=topnav_lang_ais" id="icp-nav-flyout">
#  <span class="icp-nav-link-inner">
#  <span class="nav-line-1">
#  </span>
#  <span class="nav-line-2">
#  <span class="icp-nav-flag icp-nav-flag-us icp-nav-flag-discoverability-t1"></span>
#  <div>EN</div>
#  <span class="nav-icon nav-arrow" style="visibility: visible;"></span>
#  </span>
#  </span>
#  </a>,
# ...

# %%
link_tag = soup_selenium.find_all('link',href=True)
link_tag
def extract_text(tag, atribute):
    return tag.text

print(list(map(extract_text, link_tag,'href')))

# %%
# Grab the H2

#h2_grab = soup_selenium.find_all('h2', {'class': "a-color-base headline truncate-2line"})
h2_grab = soup_selenium.find_all('h2')
#h2_grab[0].get_text()
# h2_grab[0].text #grab one

list(map(lambda item: item.text, h2_grab))
# Out:
# ['Get fit at home',
#  'Electronics',
#  'Gaming accessories',
#  'Sign in for the best experienceSign in for the best experience',
#  'Shop by Category',
#  'Health & Personal Care',
#  'Toys Under $30',
#  'Easy returns',
#  'Beauty picks',
#  'Shop gifts for everyone on your list',
#  'Top Sellers in Books for you',
#  'International top sellers',
#  'For your Fitness Needs',
#  'Shop activity trackers and smartwatches',
#  'New arrivals in Toys',
#  'Home & Kitchen Under $30',
#  'Top Sellers in Toys for you',
#  'Home Décor Under $20',
#  'Shop Laptops & Tablets',
#  'Kindle E readers',
#  'Gifts for every stocking',
#  'Create with strip lights',
#  'Popular Gifts in Baby',
#  'Popular items this season',
#  'Gaming merchandise',
#  'Shop Pet supplies',
#  'Deals in Tools and Home Improvement',
#  'A holiday home starts here',
#  'Stuffed Animals & Toys under $10']

# %%
print(soup_selenium.h2)
# Out:
# <h2 class="a-color-base headline truncate-2line">Get fit at home</h2>

# %%
items = soup_selenium.find_all(string=re.compile("www"))
items
# Out:
# ['\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);\n\n\n    var ue_err_chan = \'jserr-rw\';\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=""+(e.location?e.location.href:"");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:""+e,err:g,fromOnEr
# ...

# %%
# Code to get the image link
# l = soup_selenium.find_all(class_ = 'a-section a-spacing-none fluid-image-container')
images = list(map(lambda img: re.findall('https\S+jpg',str(img)), soup_selenium.find_all(class_ = 'a-section a-spacing-none fluid-image-container',attrs='href')))
images
# Out:
# [['https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2020/May/Dashboard/Fuji_Dash_Beauty_2x._SY608_CB432774344_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2020/May/Dashboard/Fuji_Dash_Beauty_2x._SY608_CB432774344_.jpg'],
#  ['https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2020/May/Dashboard/Fuji_Dash_Electronics_2x._SY608_CB432774322_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2020/May/Dashboard/Fuji_Dash_Electronics_2x._SY608_CB432774322_.jpg'],
#  ['https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2021/June/Fuji_Quad_Headset_2x._SY232_CB667159060_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2021/June/Fuji_Quad_Headset_2x._SY232_CB667159060_.jpg'],
#  ['https://images-na.ssl-images-amazon.com/images/G/01/AmazonExports/Fuji/2021/June/Fuji_Quad_Keyboard_2x._SY232_CB667159063_.jpg',
# ...

# %%
# Write in the boxes and press buttons
search_box = driver.find_element_by_id('twotabsearchtextbox')

search = 'books'

# send_keys() to simulate key strokes
search_box.send_keys(search)

# # locate submit button by_class_name
search_button = driver.find_element_by_id("nav-search-submit-button")  #TODO: fix. Says the button is not there.

# # .click() to mimic button click
search_button.click()

# %%
soup_selenium_books_page = BeautifulSoup(driver.page_source, 'html.parser')
print(soup_selenium_books_page.prettify())
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-hires a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.22.2-2022-12-01" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js">
#   </script>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
# ...

# %%
driver.find_elements_by_id('gridItemRoot')[4].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [166], in <cell line: 1>()
# ----> 1 driver.find_elements_by_id('gridItemRoot')[4].text
#
# IndexError: list index out of range

# %%
driver.execute_script("window.scrollTo(0,document.body.scrollHeight/2)")

# %%
driver.find_elements_by_id('gridItemRoot')[4].text

# %%
#find the ating higest and higest price with selenium. 
#Column with names, rating, prices / highest, rating 
grab_2 = driver.find_elements_by_id('gridItemRoot')

books = list(map(lambda grab_2: grab_2.text, grab_2))
books

# %%
df = pd.DataFrame(books, columns=['nameofbook'])
df
# Out:
#                                            nameofbook
# 0   It Starts with Us: A Novel (It Ends with Us)\n...
# 1   The Light We Carry: Overcoming in Uncertain Ti...
# 2   Interesting Facts For Curious Minds: 1572 Rand...
# 3   How To Draw 101 Cute Stuff For Kids: Simple an...
# 4        It Ends with Us: A Novel (1)\n195,920\n$9.99
# 5   Harry Potter and the Order of the Phoenix: The...
# 6   Diper Överlöde (Diary of a Wimpy Kid Book 17)\...
# 7   The Complete Cookbook for Young Chefs: 100+ Re...
# 8   From Crook to Cook: Platinum Recipes from Tha ...
# 9   The Complete Baking Book for Young Chefs: 100+...
# 10  Cat Kid Comic Club: Collaborations: A Graphic ...
# 11  Atomic Habits: An Easy & Proven Way to Build G...
# 12  Faith Still Moves Mountains: Miraculous Storie...
# 13  World of Eric Carle, Around the Farm 30-Button...
# 14  Friends, Lovers, and the Big Terrible Thing: A...
# 15                            Verity\n189,083\n$11.26
# ...

# %%
# explode  'Reminders of Him: A Novel\n169,929\n$9.57',
# rating : \n169,929\
# price : \n$9.57

# %%
df['name'], df['rate'], df['prize'] = df.nameofbook.str.split('\n',2).str
# Out:
# C:\Users\hanau\AppData\Local\Temp\ipykernel_19784\1751646554.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['name'], df['rate'], df['prize'] = df.nameofbook.str.split('\n',2).str

# %%
df
df['prize'] = df['prize'].str.replace('$', '')
# Out:
# C:\Users\hanau\AppData\Local\Temp\ipykernel_19784\1683191537.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['prize'] = df['prize'].str.replace('$', '')

# %%
df.sort_values(by='rate', ascending=False)
# Out:
#                                            nameofbook  \
# 48                 Ugly Love: A Novel\n93,021\n$10.00
# 9   The Complete Baking Book for Young Chefs: 100+...
# 11  Atomic Habits: An Easy & Proven Way to Build G...
# 10  Cat Kid Comic Club: Collaborations: A Graphic ...
# 3   How To Draw 101 Cute Stuff For Kids: Simple an...
# 17                  How to Catch an Elf\n7,023\n$8.04
# 28  My First Library : Boxset of 10 Board Books fo...
# 43     I Love You to the Moon and Back\n61,688\n$4.31
# 24  Go-To Dinners: A Barefoot Contessa Cookbook\n6...
# 2   Interesting Facts For Curious Minds: 1572 Rand...
# 1   The Light We Carry: Overcoming in Uncertain Ti...
# 33  A World of Curiosities: A Novel (Chief Inspect...
# 35      Lessons in Chemistry: A Novel\n59,899\n$18.65
# 34  The Body Keeps the Score: Brain, Mind, and Bod...
# 20         The Very Hungry Caterpillar\n55,445\n$5.00
# 30  Life Skills for Teens: How to Cook, Clean, Man...
# ...

# %%
# best rating : Ugly Love: A Novel\n93,021\n$10.00	
# highest price :  Life Skills for Teens: How to Cook, Clean, Man...

# %%
# Try to grab the best sellers
_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y

# %%
soup_selenium_books_page = BeautifulSoup(driver.page_source, 'html.parser')
print(soup_selenium_books_page.prettify())
driver.find_elements_by_id('p13n-asin-index-0')[4].text
#find the ating higest and higest price with selenium. 
#Column with names, rating, prices / highest, rating 
grab_2 = driver.find_elements_by_id('p13n-asin-index-0')

books = list(map(lambda grab_2: grab_2.text, grab_2))
books
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-hires a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.22.2-2022-12-01" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js">
#   </script>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
# ...
