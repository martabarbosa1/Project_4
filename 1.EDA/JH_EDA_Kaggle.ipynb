# %%
import pandas as pd
import regex as re

# %%
df = pd.read_csv('/content/drive/MyDrive/WILD CODE SCHOOL/PROJECT 4 - WEBSCRAPING/Kaggle_2_goodreads/full_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f4df20b521ae> in <module>
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/WILD CODE SCHOOL/PROJECT 4 - WEBSCRAPING/Kaggle_2_goodreads/full_dataset.csv')
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.info()

# %%
df.head()

# %%
df['Description'].value_counts()

# %%
df['PagesNumber'].value_counts()

# %%
df['pagesNumber'].value_counts()

# %%
df['pagesnumber_diff'] = df['PagesNumber'] - df['pagesNumber']
df['pagesnumber_diff']

# %%
df['ISBN'].isna().sum()
# Out:
# 5923

# %%
# Drop rows who don't have ISBN
df.dropna(subset=['ISBN'], how='all', inplace=True)
df
# Out:
#          Unnamed: 0      Id  \
# 1                 1       2
# 3                 3       4
# 4                 4       5
# 6                 6       8
# 7                 7       9
# ...             ...     ...
# 1850305       40885  999991
# 1850306       40886  999992
# 1850307       40887  999993
# 1850308       40888  999997
# 1850309       40889  999998
#
#                                                       Name RatingDist1  \
# 1        Harry Potter and the Order of the Phoenix (Har...     1:12455
# 3        Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4        Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 6        Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7        Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# ...                                                    ...         ...
# 1850305  Gendered Talk at Work: Constructing Gender Ide...         1:0
# ...

# %%
#to_obtain_list to scrap
# df['ISBN'].to_csv('list_ISBN', index=False)

# %%
# test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projects/PROJECT 4 - WEBSCRAPING/list_ISBN')
# test
# Out:
#                ISBN
# 0        0439358078
# 1        0439554896
# 2        043965548X
# 3        0439682584
# 4        0976540606
# ...             ...
# 1844382  1405117591
# 1844383  0312104715
# 1844384  0761124209
# 1844385  1560248572
# 1844386  097495974X
#
# [1844387 rows x 1 columns]

# %% [markdown]
# # cleaning the RatingDistTotal column

# %%
new = df["RatingDistTotal"].str.split(':', expand=True)
new
# Out:
#              0        1
# 1        total  2358637
# 3        total  2560657
# 4        total  2610317
# 6        total    43968
# 7        total       28
# ...        ...      ...
# 1850305  total       25
# 1850306  total        0
# 1850307  total      121
# 1850308  total        0
# 1850309  total        2
#
# [1844387 rows x 2 columns]

# %%
df["RatingDistTotal_split"]= new[1]

# %%
# Drop the old column RatingDistTotal and the columns we won't study
df = df.drop(['PublishDay', 'PublishMonth', 'Language', 'RatingDistTotal'], axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Name', 'RatingDist1', 'pagesNumber', 'RatingDist4',
#        'Publisher', 'CountsOfReview', 'PublishYear', 'Authors', 'Rating',
#        'RatingDist2', 'RatingDist5', 'ISBN', 'RatingDist3', 'Description',
#        'Count of text reviews', 'PagesNumber', 'RatingDistTotal_split'],
#       dtype='object')

# %%
df.info()

# %%
new2 = df['RatingDist1'].str.split(':', expand=True)
new2
# Out:
#          0      1
# 1        1  12455
# 3        1  11896
# 4        1  10128
# 6        1    402
# 7        1      0
# ...     ..    ...
# 1850305  1      0
# 1850306  1      0
# 1850307  1      2
# 1850308  1      0
# 1850309  1      0
#
# [1844387 rows x 2 columns]

# %%
df
# Out:
#          Unnamed: 0      Id  \
# 1                 1       2
# 3                 3       4
# 4                 4       5
# 6                 6       8
# 7                 7       9
# ...             ...     ...
# 1850305       40885  999991
# 1850306       40886  999992
# 1850307       40887  999993
# 1850308       40888  999997
# 1850309       40889  999998
#
#                                                       Name  pagesNumber  \
# 1        Harry Potter and the Order of the Phoenix (Har...        870.0
# 3        Harry Potter and the Chamber of Secrets (Harry...        352.0
# 4        Harry Potter and the Prisoner of Azkaban (Harr...        435.0
# 6        Harry Potter Boxed Set, Books 1-5 (Harry Potte...       2690.0
# 7        Unauthorized Harry Potter Book Seven News: "Ha...        152.0
# ...                                                    ...          ...
# 1850305  Gendered Talk at Work: Constructing Gender Ide...        251.0
# ...

# %%
df["RatingDist1_final"]= new2[1]
df = df.drop(['RatingDist1'], axis=1)

# %%
new3 = df['RatingDist2'].str.split(':', expand=True)
new3

df["RatingDist2_final"]= new3[1]
df = df.drop(['RatingDist2'], axis=1)

# %%
new4 = df['RatingDist3'].str.split(':', expand=True)
new4

df["RatingDist3_final"]= new4[1]
df = df.drop(['RatingDist3'], axis=1)

# %%
new5 = df['RatingDist4'].str.split(':', expand=True)
new5

df["RatingDist4_final"]= new5[1]
df = df.drop(['RatingDist4'], axis=1)

# %%
new6 = df['RatingDist5'].str.split(':', expand=True)
new6

df["RatingDist5_final"]= new6[1]
df = df.drop(['RatingDist5'], axis=1)

# %%
df
# Out:
#          Unnamed: 0      Id  \
# 1                 1       2
# 3                 3       4
# 4                 4       5
# 6                 6       8
# 7                 7       9
# ...             ...     ...
# 1850305       40885  999991
# 1850306       40886  999992
# 1850307       40887  999993
# 1850308       40888  999997
# 1850309       40889  999998
#
#                                                       Name  pagesNumber  \
# 1        Harry Potter and the Order of the Phoenix (Har...        870.0
# 3        Harry Potter and the Chamber of Secrets (Harry...        352.0
# 4        Harry Potter and the Prisoner of Azkaban (Harr...        435.0
# 6        Harry Potter Boxed Set, Books 1-5 (Harry Potte...       2690.0
# 7        Unauthorized Harry Potter Book Seven News: "Ha...        152.0
# ...                                                    ...          ...
# 1850305  Gendered Talk at Work: Constructing Gender Ide...        251.0
# ...

# %%
#df.info()
# convert the rating int 

df[['RatingDistTotal_split','RatingDist1_final','RatingDist2_final','RatingDist3_final','RatingDist4_final','RatingDist5_final']] = df[['RatingDistTotal_split','RatingDist1_final','RatingDist2_final','RatingDist3_final','RatingDist4_final','RatingDist5_final']].astype(str).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1844387 entries, 1 to 1850309
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             int64
#  1   Id                     int64
#  2   Name                   object
#  3   pagesNumber            float64
#  4   Publisher              object
#  5   CountsOfReview         int64
#  6   PublishYear            int64
#  7   Authors                object
#  8   Rating                 float64
#  9   ISBN                   object
#  10  Description            object
#  11  Count of text reviews  float64
#  12  PagesNumber            float64
#  13  RatingDistTotal_split  int64
#  14  RatingDist1_final      int64
#  15  RatingDist2_final      int64
#  16  RatingDist3_final      int64
#  17  RatingDist4_final      int64
#  18  RatingDist5_final      int64
# dtypes: float64(4), int64(10), object(5)
# memory usage: 281.4+ MB

# %%
# Drop books who have "unknown" and "anonymous"
df.drop(df[(df['Authors']=="Anonymous") | (df['Authors']=="Unknown") ].index, inplace=True)

# %%
# Drop Count of text reviews	 because too many NaNs

# %%
df.to_csv("Clean_data.csv")

# %%
df = pd.read_csv('/content/drive/MyDrive/WILD CODE SCHOOL/PROJECT 4 - WEBSCRAPING/Dataset clean/Clean_data.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                     0
# Unnamed: 0.1                   0
# Id                             0
# Name                           0
# pagesNumber              1009480
# Publisher                  17497
# CountsOfReview                 0
# PublishYear                    0
# Authors                        0
# Rating                         0
# ISBN                           0
# Description               673619
# Count of text reviews    1432096
# PagesNumber               830020
# RatingDistTotal_split          0
# RatingDist1_final              0
# RatingDist2_final              0
# RatingDist3_final              0
# RatingDist4_final              0
# RatingDist5_final              0
# dtype: int64

# %%
df.corr()
# Out:
#                        Unnamed: 0  Unnamed: 0.1        Id  pagesNumber  \
# Unnamed: 0               1.000000      0.134117  0.240865    -0.001331
# Unnamed: 0.1             0.134117      1.000000  0.598418     0.000107
# Id                       0.240865      0.598418  1.000000    -0.000200
# pagesNumber             -0.001331      0.000107 -0.000200     1.000000
# CountsOfReview          -0.027456     -0.021710 -0.041516     0.000577
# PublishYear             -0.008347     -0.007900 -0.016270     0.000073
# Rating                  -0.112420     -0.189367 -0.322308    -0.000926
# Count of text reviews    0.016765      0.004820 -0.017245     0.000257
# PagesNumber              0.000926      0.000163  0.000944          NaN
# RatingDistTotal_split   -0.012829     -0.023336 -0.032388     0.000604
# RatingDist1_final       -0.008733     -0.016432 -0.022104     0.000393
# RatingDist2_final       -0.012262     -0.023285 -0.031745     0.000413
# ...

# %% [markdown]
# ## Try on 3 books: Create the function to grab the price for the paperback and hardcover

# %%
df = pd.read_csv('/content/drive/MyDrive/WILD CODE SCHOOL/PROJECT 4 - WEBSCRAPING/Amazon_WebScrapping/Trial on 3 books - Python/Test')
df
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  ['  Kindle  \n $12.99  \n   \n  \n\n          ...
# 1           1  ['  Kindle  \n $16.99  \n   \n  \n\n          ...
# 2           2  ['  Kindle  \n $14.99  \n   \n  \n\n          ...
# 3           3                                                 []
# 4           4  ['  Paperback  \n $28.79  \n\n\n   \n     3 Us...
#
#                       1
# 0         Atomic Habits
# 1    The Light We Carry
# 2  I'm Glad My Mom Died
# 3             1234567tt
# 4         pão de açúcar

# %%
# Dropping the row 3 which was a test 
#df.drop(labels=[3], axis=0, inplace=True)

# %%
df['0'][1]
# Out:
# "['  Kindle  \\n $16.99  \\n   \\n  \\n\\n                                    Read with Our  Free App  \\n\\n    ', '  \\n\\n\\n  \\n Audiobook    \\n  \\n\\n $0.00  \\n\\n\\n \\n\\n\\n   \\n \\n \\n Free with your Audible trial    \\n ', '  Hardcover  \\n    \\n                             from $15.95                \\n\\n\\n   \\n     8 Used from $15.95         37 New from $19.84      ', '  Paperback  \\n $31.50  \\n\\n\\n   \\n     5 Used from $23.83         21 New from $23.95      ', '  Audio CD  \\n $38.78  \\n\\n\\n   \\n     5 Used from $27.08         17 New from $27.12      ']"

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '0', '1'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      int64
#  1   0           5 non-null      object
#  2   1           5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
# code working for the paperback
re.findall('Paperback\s\s.n\s.[[0-9]+\.[0-9]+', df['0'][1])
# Out:
# ['Paperback  \\n $31.50']

# %%
# ISOLATING THE PRICE 
re.findall('(?<=Paperback\s\s.n\s.)[[0-9]+\.[0-9]+', df['0'][1])
# Out:
# ['31.50']

# %%
# write a function
# not working, need to find a way to get the price per book 
def get_price(book):
  return(re.findall('(?<=Paperback\s\s.n\s.)[[0-9]+\.[0-9]+', book))

df['price_paperback'] = list(map(get_price,df['0']))

#df['0'].apply(lambda tag: get_price(book))

# %%
def get_price_hardcover(book):
  return(re.findall('(?<=Hardcover\s\s.n\s.)[[0-9]+\.[0-9]+', book))
df['price_hardcover'] = list(map(get_price_hardcover,df['0']))

# %%
df
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  ['  Kindle  \n $12.99  \n   \n  \n\n          ...
# 1           1  ['  Kindle  \n $16.99  \n   \n  \n\n          ...
# 2           2  ['  Kindle  \n $14.99  \n   \n  \n\n          ...
# 3           3                                                 []
# 4           4  ['  Paperback  \n $28.79  \n\n\n   \n     3 Us...
#
#                       1 price_paperback price_hardcover
# 0         Atomic Habits         [14.90]         [11.98]
# 1    The Light We Carry         [31.50]              []
# 2  I'm Glad My Mom Died              []         [17.28]
# 3             1234567tt              []              []
# 4         pão de açúcar         [28.79]              []

# %%
type(df['price_hardcover'][0])
# Out:
# list

# %%
df['price_hardcover'] = df['price_hardcover'].str[0]
df['price_paperback'] = df['price_paperback'].str[0]

#df['price_hardcover'] = df['price_hardcover'].str[0].astype(float)
#df['price_paperback'] = df['price_paperback'].str[0].astype(float)

# %%
df
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  ['  Kindle  \n $12.99  \n   \n  \n\n          ...
# 1           1  ['  Kindle  \n $16.99  \n   \n  \n\n          ...
# 2           2  ['  Kindle  \n $14.99  \n   \n  \n\n          ...
# 3           3                                                 []
# 4           4  ['  Paperback  \n $28.79  \n\n\n   \n     3 Us...
#
#                       1 price_paperback price_hardcover
# 0         Atomic Habits           14.90           11.98
# 1    The Light We Carry           31.50             NaN
# 2  I'm Glad My Mom Died             NaN           17.28
# 3             1234567tt             NaN             NaN
# 4         pão de açúcar           28.79             NaN

# %%
df['price_paperback'] = df['price_paperback'].astype(float)
df['price_hardcover'] = df['price_hardcover'].astype(float)

# %%
df
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  ['  Kindle  \n $12.99  \n   \n  \n\n          ...
# 1           1  ['  Kindle  \n $16.99  \n   \n  \n\n          ...
# 2           2  ['  Kindle  \n $14.99  \n   \n  \n\n          ...
# 3           3                                                 []
# 4           4  ['  Paperback  \n $28.79  \n\n\n   \n     3 Us...
#
#                       1  price_paperback  price_hardcover
# 0         Atomic Habits            14.90            11.98
# 1    The Light We Carry            31.50              NaN
# 2  I'm Glad My Mom Died              NaN            17.28
# 3             1234567tt              NaN              NaN
# 4         pão de açúcar            28.79              NaN

# %%
type(df['price_hardcover'][0])
# Out:
# numpy.float64

# %%
# harcover all
re.findall('Hardcover\s\s.n\s.[[0-9]+\.[0-9]+', df['0'][2])
# Out:
# ['Hardcover  \\n $17.28']

# %%
# Price for the Hardcover  
result = re.findall('(?<=Hardcover\s\s.n\s.)[[0-9]+\.[0-9]+', df['0'][2])

# %% [markdown]
# ## OTHER CODE NOT WORKING

# %%
re.findall('Paperback\s\s.n\s.[0-9]+\.[0-9]+[^[a-zA-Z]]', df['0'][1])
# Out:
# []

# %%
re.findall('(?!Paperback\s+\S+)[0-9]+\.[0-9]+', df['0'][1])
# Out:
# ['16.99',
#  '0.00',
#  '15.95',
#  '15.95',
#  '19.84',
#  '31.50',
#  '23.83',
#  '23.95',
#  '38.78',
#  '27.08',
#  '27.12']

# %%
re.findall('[Paperback\s\s.n\s.]([0-9]+\.[0-9]+)', df['0'][1])

grade = re.findall("[\d]{1,2}/[\d]{1,2} ", text)
print(grade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-4eee60ae96a6> in <module>
#       1 re.findall('[Paperback\s\s.n\s.]([0-9]+\.[0-9]+)', df['0'][1])
#       2
# ----> 3 grade = re.findall("[\d]{1,2}/[\d]{1,2} ", text)
#       4 print(grade)
#
# NameError: name 'text' is not defined

# %%
“[a-zA-Z]+([0-9]+)" 

	Creates a subexpression within a larger expression. Useful with the "or" perator (i.e. | ), and when extracting and replacing values. For example, if I wanted to extract a numeric value which I know follows directly after a word or set of letters, I could use the regular expression “[a-zA-Z]+([0-9]+)" this matches the whole expression, but allows you to select the 
portion in the parentheses (called a substring). Handling substrings is discussed in greater detail below.

# %%
    # isolate the expression
# re.findall('Paperback\s\s.n\s.[0-9]+\.[0-9]+', df['0'][1]).find('[0-9]+\.[0-9]+') # not working

#Other try with | but displaying all the prices
re.findall('Paperback\s\s.n\s.|[0-9]+\.[0-9]+', df['0'][1])

# Other try with this /^[0-9]*$/ to display just numbers OR ^[0-9]+$ > doesn't catch anything
re.findall('Paperback\s\s.n\s.[0-9]+\.[0-9]+/^[0-9]*$/', df['0'][1])

# other try with \d+ to match one or more digits
re.findall(('Paperback\s\s.n\s.[0-9]+\.[0-9]+')('\d+'), df['0'][1])

# other try with \D to match one or more digits
re.findall(('Paperback\s\s.n\s.[0-9]+\.[0-9]+')('\d+'), df['0'][1])

# trying with [] and / and ()
re.findall('[Paperback\s\s.n\s.]/([0-9]+\.[0-9]+)', df['0'][1])

# %%
re.findall(('Paperback\s\s.n\s.[0-9]+\.[0-9]+[^aA]'), df['0'][1])

# %%
# other try with [^A-Z] to just show the price 
re.findall('Paperback\s\s.n\s.[0-9]+\.[0-9]$([^A-Z])', df['0'][1])

# %%
# grab just the format 
re.findall('Paperback\s\s.n\s', df['0'][1])

# %%
# grab all the prices
re.findall('[0-9]+\.[0-9]+', df['0'][1])

# %%
df.columns

# %%
type(df)
